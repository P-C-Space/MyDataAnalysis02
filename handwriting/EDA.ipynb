# %% [markdown]
# ### 사용할 라이브러리

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_path = "../data/train/"

# %%
import pathlib
from glob import glob

image_count = len(list(pathlib.Path(train_path).glob('*.png')))
print(image_count)
# Out:
# 76888

# %%
data = pd.read_csv('../data/train.csv')

# %%
data.head() # 처음 다섯개의 데이터
# Out:
#             id                 img_path label
# 0  TRAIN_00000  ./train/TRAIN_00000.png   빨간색
# 1  TRAIN_00001  ./train/TRAIN_00001.png     머
# 2  TRAIN_00002  ./train/TRAIN_00002.png    차차
# 3  TRAIN_00003  ./train/TRAIN_00003.png     써
# 4  TRAIN_00004  ./train/TRAIN_00004.png   놓치다

# %%
data.tail() # 끝 다섯개의 데이터
# Out:
#                 id                 img_path label
# 76883  TRAIN_76883  ./train/TRAIN_76883.png     회
# 76884  TRAIN_76884  ./train/TRAIN_76884.png    겪다
# 76885  TRAIN_76885  ./train/TRAIN_76885.png    벨트
# 76886  TRAIN_76886  ./train/TRAIN_76886.png     톼
# 76887  TRAIN_76887  ./train/TRAIN_76887.png    자리

# %%
data.info() # 데이터 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76888 entries, 0 to 76887
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        76888 non-null  object
#  1   img_path  76888 non-null  object
#  2   label     76888 non-null  object
# dtypes: object(3)
# memory usage: 1.8+ MB

# %%
data.label.unique()
# Out:
# array(['빨간색', '머', '차차', ..., '푿', '풉', '엿'], dtype=object)

# %%
len(data.label.unique()) # 라벨의 수 5628개의 범주
# Out:
# 5628

# %%
data['len'] = data['label'].str.len()

# %%
data_count = pd.DataFrame(data['len'].value_counts())
data_count
# Out:
#      len
# 2  28631
# 1  23703
# 3  13514
# 4   9988
# 5   1026
# 6     26

# %%
img = {'../data/train/TRAIN_00000.png',
        '../data/train/TRAIN_00001.png',
        '../data/train/TRAIN_00002.png',
        '../data/train/TRAIN_00003.png',
        '../data/train/TRAIN_00004.png',
        '../data/train/TRAIN_00005.png',
        '../data/train/TRAIN_00006.png',
        '../data/train/TRAIN_00007.png',
        '../data/train/TRAIN_00008.png',
        '../data/train/TRAIN_00009.png'}

name_kor = []
name_kor = data.label.head(10).values
name = ['red','mu','chacha','ssu','miss','old','month','bin','hand','number']

print(name)
# Out:
# ['red', 'mu', 'chacha', 'ssu', 'miss', 'old', 'month', 'bin', 'hand', 'number']

# %%
plt.figure(figsize=(20,20))
columns = 5
for i, image in enumerate(img):
    plt.subplot(len(img)//columns + 1, columns, i + 1)
    image=plt.imread(image)
    plt.title(name[i])
    plt.imshow(image)
