# %%
import numpy as np
import pandas as pd
# from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
# import sklearn

# %%
import os

# %% [markdown]
# ---

# %%
train  = pd.read_csv('./data/train.csv')
test  = pd.read_csv('./data/test.csv')

train = train.drop(['index'],axis = 1)
test =test.drop(['index'],axis = 1)

# %%
concat_features = train

mask = concat_features.introelapse > (concat_features.introelapse.quantile(0.75) + 1.5 * (concat_features.introelapse.quantile(0.75) - concat_features.introelapse.quantile(0.25)))
concat_features.introelapse[mask] = concat_features.introelapse.quantile(0.75)

mask = concat_features.testelapse > (concat_features.testelapse.quantile(0.75) + 1.5 * (concat_features.testelapse.quantile(0.75) - concat_features.testelapse.quantile(0.25)))
concat_features.testelapse[mask] = concat_features.testelapse.quantile(0.75)

mask = concat_features.surveyelapse > (concat_features.surveyelapse.quantile(0.75) + 1.5 * (concat_features.surveyelapse.quantile(0.75) - concat_features.surveyelapse.quantile(0.25)))
concat_features.surveyelapse[mask] = concat_features.surveyelapse.quantile(0.75)

train = concat_features



concat_features = test

mask = concat_features.introelapse > (concat_features.introelapse.quantile(0.75) + 1.5 * (concat_features.introelapse.quantile(0.75) - concat_features.introelapse.quantile(0.25)))
concat_features.introelapse[mask] = concat_features.introelapse.quantile(0.75)

mask = concat_features.testelapse > (concat_features.testelapse.quantile(0.75) + 1.5 * (concat_features.testelapse.quantile(0.75) - concat_features.testelapse.quantile(0.25)))
concat_features.testelapse[mask] = concat_features.testelapse.quantile(0.75)

mask = concat_features.surveyelapse > (concat_features.surveyelapse.quantile(0.75) + 1.5 * (concat_features.surveyelapse.quantile(0.75) - concat_features.surveyelapse.quantile(0.25)))
concat_features.surveyelapse[mask] = concat_features.surveyelapse.quantile(0.75)

test = concat_features

# %%
for name in ['education', 'urban', 'gender', 'engnat', 'hand', 'religion',
            'voted', 'married']:

    mergedata = pd.get_dummies(train[name], prefix = name)
    train = pd.concat([train, mergedata], axis=1)
    train = train.drop([name], axis = 1)

# %%
for name in ['education', 'urban', 'gender', 'engnat', 'hand', 'religion',
            'voted', 'married']:

    mergedata = pd.get_dummies(test[name], prefix = name)
    test = pd.concat([test, mergedata], axis=1)
    test = test.drop([name], axis = 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 94 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Q1             14959 non-null  float64
#  1   Q2             14931 non-null  float64
#  2   Q3             14950 non-null  float64
#  3   Q4             14929 non-null  float64
#  4   Q5             14962 non-null  float64
#  5   Q6             14952 non-null  float64
#  6   Q7             14924 non-null  float64
#  7   Q8             14952 non-null  float64
#  8   Q9             14944 non-null  float64
#  9   Q10            14928 non-null  float64
#  10  Q11            14941 non-null  float64
#  11  Q12            14933 non-null  float64
#  12  Q13            14960 non-null  float64
#  13  Q14            14964 non-null  float64
#  14  Q15            14955 non-null  float64
#  15  Q16            14967 non-null  float64
#  16  Q17            14963 non-null  float64
#  17  Q18            14937 non-null  float64
#  18  Q19            14947 non-null  float64
#  19  Q20            14955 non-null  float64
#  20  Q21            14961 non-null  float64
#  21  Q22            14962 non-null  float64
#  22  Q23            14950 non-null  float64
#  23  Q24            14939 non-null  float64
#  24  Q25            14956 non-null  float64
#  25  Q26            14932 non-null  float64
#  26  country        14810 non-null  object
#  27  introelapse    15000 non-null  int64
#  28  testelapse     15000 non-null  int64
#  29  surveyelapse   15000 non-null  int64
#  30  TIPI1          14947 non-null  float64
#  31  TIPI2          14934 non-null  float64
#  32  TIPI3          14921 non-null  float64
#  33  TIPI4          14936 non-null  float64
#  34  TIPI5          14930 non-null  float64
#  35  TIPI6          14938 non-null  float64
#  36  TIPI7          14936 non-null  float64
#  37  TIPI8          14935 non-null  float64
#  38  TIPI9          14936 non-null  float64
#  39  TIPI10         14920 non-null  float64
#  40  VCL1           15000 non-null  int64
#  41  VCL2           15000 non-null  int64
#  42  VCL3           15000 non-null  int64
#  43  VCL4           15000 non-null  int64
#  44  VCL5           15000 non-null  int64
#  45  VCL6           15000 non-null  int64
#  46  VCL7           15000 non-null  int64
#  47  VCL8           15000 non-null  int64
#  48  VCL9           15000 non-null  int64
#  49  VCL10          15000 non-null  int64
#  50  VCL11          15000 non-null  int64
#  51  VCL12          15000 non-null  int64
#  52  VCL13          15000 non-null  int64
#  53  VCL14          15000 non-null  int64
#  54  VCL15          15000 non-null  int64
#  55  VCL16          15000 non-null  int64
#  56  age            15000 non-null  int64
#  57  orientation    14601 non-null  float64
#  58  familysize     14681 non-null  float64
#  59  ASD            14911 non-null  float64
#  60  nerdiness      15000 non-null  int64
#  61  education_1.0  15000 non-null  uint8
#  62  education_2.0  15000 non-null  uint8
#  63  education_3.0  15000 non-null  uint8
#  64  education_4.0  15000 non-null  uint8
#  65  urban_0        15000 non-null  uint8
#  66  urban_1        15000 non-null  uint8
#  67  urban_2        15000 non-null  uint8
#  68  urban_3        15000 non-null  uint8
#  69  gender_1.0     15000 non-null  uint8
#  70  gender_2.0     15000 non-null  uint8
#  71  gender_3.0     15000 non-null  uint8
#  72  engnat_1.0     15000 non-null  uint8
#  73  engnat_2.0     15000 non-null  uint8
#  74  hand_1.0       15000 non-null  uint8
#  75  hand_2.0       15000 non-null  uint8
#  76  hand_3.0       15000 non-null  uint8
#  77  religion_1.0   15000 non-null  uint8
#  78  religion_2.0   15000 non-null  uint8
#  79  religion_3.0   15000 non-null  uint8
#  80  religion_4.0   15000 non-null  uint8
#  81  religion_5.0   15000 non-null  uint8
#  82  religion_6.0   15000 non-null  uint8
#  83  religion_7.0   15000 non-null  uint8
#  84  religion_8.0   15000 non-null  uint8
#  85  religion_9.0   15000 non-null  uint8
#  86  religion_10.0  15000 non-null  uint8
#  87  religion_11.0  15000 non-null  uint8
#  88  religion_12.0  15000 non-null  uint8
#  89  voted_1.0      15000 non-null  uint8
#  90  voted_2.0      15000 non-null  uint8
#  91  married_1.0    15000 non-null  uint8
#  92  married_2.0    15000 non-null  uint8
#  93  married_3.0    15000 non-null  uint8
# dtypes: float64(39), int64(21), object(1), uint8(33)
# memory usage: 7.5+ MB

# %%
train.introelapse.plot()
# Out:
# <AxesSubplot: >

# %%
train['Ex'] = train['TIPI1']-train['TIPI6']
train['Ag'] = train['TIPI7']-train['TIPI2']
train['Con'] = train['TIPI3']-train['TIPI8']
train['Es'] =train['TIPI9']-train['TIPI4']
train['Op'] =train['TIPI5']-train['TIPI10']

# %%
test['Ex'] = test['TIPI1']-test['TIPI6']
test['Ag'] = test['TIPI7']-test['TIPI2']
test['Con'] = test['TIPI3']-test['TIPI8']
test['Es'] =test['TIPI9']-test['TIPI4']
test['Op'] =test['TIPI5']-test['TIPI10']

# %%
train = train.drop(['TIPI1','TIPI2','TIPI3','TIPI4','TIPI5',
                   'TIPI6','TIPI7','TIPI8','TIPI9','TIPI10'],axis = 1)

test = test.drop(['TIPI1','TIPI2','TIPI3','TIPI4','TIPI5',
                   'TIPI6','TIPI7','TIPI8','TIPI9','TIPI10'],axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
ex = LabelEncoder()

con5 = train.country.value_counts().keys()[:5]

for i in range(train.count().max()):
    if(train.country.values[i] not in con5):
        train.country.values[i] = "X"

for i in range(test.count().max()):
    if(test.country.values[i] not in con5):
        test.country.values[i] = "X"

train.country = ex.fit_transform(train.country)

test.country = ex.fit_transform(test.country)

# %% [markdown]
# ---

# %%
# pip install pycaret

# %%
from pycaret.classification import *

model = setup(data = train, target = 'nerdiness',use_gpu=True,session_id=2023)
# Out:
# <style type="text/css">
# #T_e0962_row5_col1, #T_e0962_row18_col1, #T_e0962_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e0962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0962_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e0962_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0962_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e0962_row0_col1" class="data row0 col1" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0962_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e0962_row1_col1" class="data row1 col1" >nerdiness</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0962_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_e0962_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0962_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_e0962_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0962_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_e0962_row4_col1" class="data row4 col1" >(15000, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0962_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_e0962_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0962_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_e0962_row6_col1" class="data row6 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0962_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_e0962_row7_col1" class="data row7 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0962_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_e0962_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0962_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_e0962_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e0962_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_e0962_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e0962_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_e0962_row11_col1" class="data row11 col1" >(10499, 289)</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e0962_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_e0962_row12_col1" class="data row12 col1" >(4501, 289)</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e0962_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_e0962_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e0962_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_e0962_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e0962_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e0962_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e0962_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e0962_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e0962_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e0962_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e0962_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e0962_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e0962_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e0962_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e0962_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e0962_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e0962_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e0962_row21_col1" class="data row21 col1" >c8f5</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e0962_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_e0962_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e0962_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e0962_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e0962_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_e0962_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e0962_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e0962_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e0962_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_e0962_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e0962_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e0962_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e0962_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e0962_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e0962_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_e0962_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0962_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e0962_row30_col0" class="data row30 col0" >Normalize Meth

# %%
# best_3 = compare_models(sort = 'AUC', n_select = 3)

# %%
Top3 = compare_models(sort='Accuracy',n_select=3)
# Out:
# <style type="text/css">
# #T_f3faf th {
#   text-align: left;
# }
# #T_f3faf_row0_col0, #T_f3faf_row0_col3, #T_f3faf_row1_col0, #T_f3faf_row1_col1, #T_f3faf_row1_col2, #T_f3faf_row1_col3, #T_f3faf_row1_col4, #T_f3faf_row1_col5, #T_f3faf_row1_col6, #T_f3faf_row1_col7, #T_f3faf_row2_col0, #T_f3faf_row2_col1, #T_f3faf_row2_col2, #T_f3faf_row2_col3, #T_f3faf_row2_col4, #T_f3faf_row2_col5, #T_f3faf_row2_col6, #T_f3faf_row2_col7, #T_f3faf_row3_col0, #T_f3faf_row3_col1, #T_f3faf_row3_col2, #T_f3faf_row3_col3, #T_f3faf_row3_col4, #T_f3faf_row3_col5, #T_f3faf_row3_col6, #T_f3faf_row3_col7, #T_f3faf_row4_col0, #T_f3faf_row4_col1, #T_f3faf_row4_col2, #T_f3faf_row4_col3, #T_f3faf_row4_col4, #T_f3faf_row4_col5, #T_f3faf_row4_col6, #T_f3faf_row4_col7, #T_f3faf_row5_col0, #T_f3faf_row5_col1, #T_f3faf_row5_col2, #T_f3faf_row5_col3, #T_f3faf_row5_col4, #T_f3faf_row5_col5, #T_f3faf_row5_col6, #T_f3faf_row5_col7, #T_f3faf_row6_col0, #T_f3faf_row6_col1, #T_f3faf_row6_col2, #T_f3faf_row6_col3, #T_f3faf_row6_col4, #T_f3faf_row6_col5, #T_f3faf_row6_col6, #T_f3faf_row6_col7, #T_f3faf_row7_col0, #T_f3faf_row7_col1, #T_f3faf_row7_col2, #T_f3faf_row7_col3, #T_f3faf_row7_col4, #T_f3faf_row7_col5, #T_f3faf_row7_col6, #T_f3faf_row7_col7, #T_f3faf_row8_col0, #T_f3faf_row8_col1, #T_f3faf_row8_col2, #T_f3faf_row8_col3, #T_f3faf_row8_col4, #T_f3faf_row8_col5, #T_f3faf_row8_col6, #T_f3faf_row8_col7, #T_f3faf_row9_col0, #T_f3faf_row9_col1, #T_f3faf_row9_col2, #T_f3faf_row9_col3, #T_f3faf_row9_col4, #T_f3faf_row9_col5, #T_f3faf_row9_col6, #T_f3faf_row9_col7, #T_f3faf_row10_col0, #T_f3faf_row10_col1, #T_f3faf_row10_col2, #T_f3faf_row10_col3, #T_f3faf_row10_col4, #T_f3faf_row10_col5, #T_f3faf_row10_col6, #T_f3faf_row10_col7, #T_f3faf_row11_col0, #T_f3faf_row11_col1, #T_f3faf_row11_col2, #T_f3faf_row11_col3, #T_f3faf_row11_col4, #T_f3faf_row11_col5, #T_f3faf_row11_col6, #T_f3faf_row11_col7, #T_f3faf_row12_col0, #T_f3faf_row12_col1, #T_f3faf_row12_col2, #T_f3faf_row12_col3, #T_f3faf_row12_col4, #T_f3faf_row12_col5, #T_f3faf_row12_col6, #T_f3faf_row12_col7, #T_f3faf_row13_col0, #T_f3faf_row13_col1, #T_f3faf_row13_col2, #T_f3faf_row13_col3, #T_f3faf_row13_col4, #T_f3faf_row13_col5, #T_f3faf_row13_col6, #T_f3faf_row13_col7, #T_f3faf_row14_col0, #T_f3faf_row14_col1, #T_f3faf_row14_col2, #T_f3faf_row14_col3, #T_f3faf_row14_col4, #T_f3faf_row14_col5, #T_f3faf_row14_col6, #T_f3faf_row14_col7, #T_f3faf_row15_col0, #T_f3faf_row15_col1, #T_f3faf_row15_col2, #T_f3faf_row15_col4, #T_f3faf_row15_col5, #T_f3faf_row15_col6, #T_f3faf_row15_col7 {
#   text-align: left;
# }
# #T_f3faf_row0_col1, #T_f3faf_row0_col2, #T_f3faf_row0_col4, #T_f3faf_row0_col5, #T_f3faf_row0_col6, #T_f3faf_row0_col7, #T_f3faf_row15_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f3faf_row0_col8, #T_f3faf_row1_col8, #T_f3faf_row2_col8, #T_f3faf_row3_col8, #T_f3faf_row4_col8, #T_f3faf_row5_col8, #T_f3faf_row6_col8, #T_f3faf_row7_col8, #T_f3faf_row8_col8, #T_f3faf_row9_col8, #T_f3faf_row10_col8, #T_f3faf_row11_col8, #T_f3faf_row12_col8, #T_f3faf_row13_col8, #T_f3faf_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f3faf_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f3faf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3faf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f3faf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f3faf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f3faf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f3faf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f3faf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f3faf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f3faf_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f3faf_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3faf_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_f3faf_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_f3faf_row0_col1" class="data row0 col1" >0.7723</td>
#       <td id="T_f3faf_row0_col2" class="data row0 col2" >0.8609</td>
#       <td id="T_f3faf_row0_col3" class="data row0 col3" >0.8320</td>
#       <td id="T_f3faf_row0_col4" class="data row0 col4" >0.7764</td>
#       <td id="T_f3faf_row0_col5" class="data row0 col5" >0.8032</td>
#       <td id="T_f3faf_row0_col6" class="data row0 col6" >0.5338</td>
#       <td id="T_f3faf_row0_col7" class="data row0 col7" >0.5358</td>
#       <td id="T_f3faf_row0_col8" class="data row0 col8" >1.4930</td>
#     </tr>
#     <tr>
#       <th id="T_f3faf_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_f3faf_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_f3faf_row1_col1" class="data row1 col1" >0.7697</td>
#       <td id="T_f3faf_row1_col2" class="data row1 col2" >0.8561</td>
#       <td id="T_f3faf_row1_col3" class="data row1 col3" >0.8393</td>
#       <td id="T_f3faf_row1_col4" class="data row1 col4" >0.7695</td>
#       <td id="T_f3faf_row1_col5" class="data row1 col5" >0.8028</td>
#       <td id="T_f3faf_row1_col6" class="data row1 col6" >0.5273</td>
#       <td id="T_f3faf_row1_col7" class="data row1 col7" >0.5303</td>
#       <td id="T_f3faf_row1_col8" class="data row1 col8" >1.0970</td>
#     </tr>
#     <tr>
#       <th id="T_f3faf_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_f3faf_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_f3faf_row2_col1" class="data row2 col1" >0.7569</td>
#       <td id="T_f3faf_row2_col2" class="data row2 col2" >0.8259</td>
#       <td id="T_f3faf_row2_col3" class="data row2 col3" >0.8216</td>
#       <td id="T_f3faf_row2_col4" class="data row2 col4" >0.7620</td>
#       <td id="T_f3faf_row2_col5" class="data row2 col5" >0.7906</td>
#       <td id="T_f3faf_row2_col6" class="data row2 col6" >0.5019</td>
#       <td id="T_f3faf_row2_col7" class="data row2 col7" >0.5040</td>
#       <td id="T_f3faf_row2_col8" class="data row2 col8" >7.3920</td>
#     </tr>
#     <tr>
#       <th id="T_f3faf_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_f3faf_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f3faf_row3_col1" class="data row3 col1" >0.7540</td>
#       <td id="T_f3faf_row3_col2" class="data row3 col2" >0.8189</td>
#       <td id="T_f3faf_row3_col3" class="data row3 col3" >0.8102</td>
#       <td id="T_f3faf_row3_col4" class="data row3 col4" >0.7638</td>
#       <td id="T_f3faf_row3_col5" class="data row3 col5" >0.7863</td>
#       <td id="T_f3faf_row3_col6" class="data row3 col6" >0.4971</td>
#       <td id="T_f3faf_row3_col7" class="data row3 col7" >0.4983</td>
#       <td id="T_f3faf_row3_col8" class="data row3 col8" >1.3040</td>
#     </tr>
#     <tr>
#       <th id="T_f3faf_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_f3faf_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f3faf_row4_col1" class="data row4 col1" >0.7485</td>
#       <td id="T_f3faf_row4_col2" class="data row4 col2" >0.8165</td>
#       <td id="T_f3faf_row4_col3" class="data row4 col3" >0.8155</td>
#       <td id="T_f3faf_row4_col4" class="data row4 col4" >0.7542</td>
#       <td id="T_f3faf_row4_col5" class="data row4 col5" >0.7836</td>
#       <td id="T_f3faf_row4_col6" class="data row4 col6" >0.4844</td>
#       <td id="T_f3faf_row4_col7" class="data row4 col7" >0.4866</td>
#       <td id="T_f3faf_row4_col8" class="data row4 col8" >1.9210</td>
#     </tr>
#     <tr>
#       <th id="T_f3faf_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_f3faf_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f3faf_row5_col1" class="data row5 col1" >0.7307</td>
#       <td id="T_f3faf_row5_

# %%
tuned_top3 = [tune_model(i) for i in Top3]
# Out:
# <style type="text/css">
# #T_4f4e9_row10_col0, #T_4f4e9_row10_col1, #T_4f4e9_row10_col2, #T_4f4e9_row10_col3, #T_4f4e9_row10_col4, #T_4f4e9_row10_col5, #T_4f4e9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4f4e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f4e9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4f4e9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4f4e9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4f4e9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4f4e9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4f4e9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4f4e9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f4e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f4e9_row0_col0" class="data row0 col0" >0.7819</td>
#       <td id="T_4f4e9_row0_col1" class="data row0 col1" >0.8603</td>
#       <td id="T_4f4e9_row0_col2" class="data row0 col2" >0.8416</td>
#       <td id="T_4f4e9_row0_col3" class="data row0 col3" >0.7841</td>
#       <td id="T_4f4e9_row0_col4" class="data row0 col4" >0.8118</td>
#       <td id="T_4f4e9_row0_col5" class="data row0 col5" >0.5533</td>
#       <td id="T_4f4e9_row0_col6" class="data row0 col6" >0.5552</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f4e9_row1_col0" class="data row1 col0" >0.7752</td>
#       <td id="T_4f4e9_row1_col1" class="data row1 col1" >0.8576</td>
#       <td id="T_4f4e9_row1_col2" class="data row1 col2" >0.8262</td>
#       <td id="T_4f4e9_row1_col3" class="data row1 col3" >0.7835</td>
#       <td id="T_4f4e9_row1_col4" class="data row1 col4" >0.8043</td>
#       <td id="T_4f4e9_row1_col5" class="data row1 col5" >0.5408</td>
#       <td id="T_4f4e9_row1_col6" class="data row1 col6" >0.5418</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f4e9_row2_col0" class="data row2 col0" >0.7581</td>
#       <td id="T_4f4e9_row2_col1" class="data row2 col1" >0.8413</td>
#       <td id="T_4f4e9_row2_col2" class="data row2 col2" >0.8058</td>
#       <td id="T_4f4e9_row2_col3" class="data row2 col3" >0.7716</td>
#       <td id="T_4f4e9_row2_col4" class="data row2 col4" >0.7883</td>
#       <td id="T_4f4e9_row2_col5" class="data row2 col5" >0.5064</td>
#       <td id="T_4f4e9_row2_col6" class="data row2 col6" >0.5071</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f4e9_row3_col0" class="data row3 col0" >0.7362</td>
#       <td id="T_4f4e9_row3_col1" class="data row3 col1" >0.8273</td>
#       <td id="T_4f4e9_row3_col2" class="data row3 col2" >0.8038</td>
#       <td id="T_4f4e9_row3_col3" class="data row3 col3" >0.7441</td>
#       <td id="T_4f4e9_row3_col4" class="data row3 col4" >0.7728</td>
#       <td id="T_4f4e9_row3_col5" class="data row3 col5" >0.4595</td>
#       <td id="T_4f4e9_row3_col6" class="data row3 col6" >0.4614</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f4e9_row4_col0" class="data row4 col0" >0.7390</td>
#       <td id="T_4f4e9_row4_col1" class="data row4 col1" >0.8176</td>
#       <td id="T_4f4e9_row4_col2" class="data row4 col2" >0.8020</td>
#       <td id="T_4f4e9_row4_col3" class="data row4 col3" >0.7484</td>
#       <td id="T_4f4e9_row4_col4" class="data row4 col4" >0.7743</td>
#       <td id="T_4f4e9_row4_col5" class="data row4 col5" >0.4659</td>
#       <td id="T_4f4e9_row4_col6" class="data row4 col6" >0.4675</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f4e9_row5_col0" class="data row5 col0" >0.7762</td>
#       <td id="T_4f4e9_row5_col1" class="data row5 col1" >0.8442</td>
#       <td id="T_4f4e9_row5_col2" class="data row5 col2" >0.8515</td>
#       <td id="T_4f4e9_row5_col3" class="data row5 col3" >0.7713</td>
#       <td id="T_4f4e9_row5_col4" class="data row5 col4" >0.8094</td>
#       <td id="T_4f4e9_row5_col5" class="data row5 col5" >0.5400</td>
#       <td id="T_4f4e9_row5_col6" class="data row5 col6" >0.5439</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f4e9_row6_col0" class="data row6 col0" >0.7648</td>
#       <td id="T_4f4e9_row6_col1" class="data row6 col1" >0.8286</td>
#       <td id="T_4f4e9_row6_col2" class="data row6 col2" >0.8055</td>
#       <td id="T_4f4e9_row6_col3" class="data row6 col3" >0.7802</td>
#       <td id="T_4f4e9_row6_col4" class="data row6 col4" >0.7926</td>
#       <td id="T_4f4e9_row6_col5" class="data row6 col5" >0.5210</td>
#       <td id="T_4f4e9_row6_col6" class="data row6 col6" >0.5214</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f4e9_row7_col0" class="data row7 col0" >0.7381</td>
#       <td id="T_4f4e9_row7_col1" class="data row7 col1" >0.8109</td>
#       <td id="T_4f4e9_row7_col2" class="data row7 col2" >0.8089</td>
#       <td id="T_4f4e9_row7_col3" class="data row7 col3" >0.7441</td>
#       <td id="T_4f4e9_row7_col4" class="data row7 col4" >0.7751</td>
#       <td id="T_4f4e9_row7_col5" class="data row7 col5" >0.4629</td>
#       <td id="T_4f4e9_row7_col6" class="data row7 col6" >0.4652</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f4e9_row8_col0" class="data row8 col0" >0.7505</td>
#       <td id="T_4f4e9_row8_col1" class="data row8 col1" >0.8422</td>
#       <td id="T_4f4e9_row8_col2" class="data row8 col2" >0.7867</td>
#       <td id="T_4f4e9_row8_col3" class="data row8 col3" >0.7709</td>
#       <td id="T_4f4e9_row8_col4" class="data row8 col4" >0.7787</td>
#       <td id="T_4f4e9_row8_col5" class="data row8 col5" >0.4928</td>
#       <td id="T_4f4e9_row8_col6" class="data row8 col6" >0.4929</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f4e9_row9_col0" class="data row9 col0" >0.7693</td>
#       <td id="T_4f4e9_row9_col1" class="data row9 col1" >0.8432</td>
#       <td id="T_4f4e9_row9_col2" class="data row9 col2" >0.8242</td>
#       <td id="T_4f4e9_row9_col3" class="data row9 col3" >0.7765</td>
#       <td id="T_4f4e9_row9_col4" class="data row9 col4" >0.7997</td>
#       <td id="T_4f4e9_row9_col5" class="data row9 col5" >0.5283</td>
#       <td id="T_4f4e9_row9_col6" class="data row9 col6" >0.5296</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4f4e9_row10_col0" class="data row10 col0" >0.7589</td>
#       <td id="T_4f4e9_row10_col1" class="data row10 col1" >0.8373</td>
#       <td id="T_4f4e9_row10_col2" class="data row10 col2" >0.8156</td>
#       <td id="T_4f4e9_row10_col3" class="data row10 col3" >0.7675</td>
#       <td id="T_4f4e9_row10_col4" class="data row10 col4" >0.7907</td>
#       <td id="T_4f4e9_row10_col5" class="data row10 col5" >0.5071</td>
#       <td id="T_4f4e9_row10_col6" class="data row10 col6" >0.5086</td>
#     </tr>
#     <tr>
#       <th id="T_4f4e9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4f4e9_row11_col0" class="data row11 col0" >0.0163</td>
#       <td id="T_4f4e9_row11_col1" class="data row11 col1" >0.0152</td>
#       <td id="T_4f4e9_row11_col2" class="data row11 col2" >0.0189</td>
#       <td id="T_4f4e9_row11_col3" class="data row11 col3" >0.0151</td>
#       <td id="T_4f4e9_row11_col4

# %%
# best_1 = compare_models(sort = 'AUC', n_select = 1)

# %%
blended = blend_models(estimator_list=tuned_top3,fold=5,method='soft')
# Out:
# <style type="text/css">
# #T_9ecc8_row5_col0, #T_9ecc8_row5_col1, #T_9ecc8_row5_col2, #T_9ecc8_row5_col3, #T_9ecc8_row5_col4, #T_9ecc8_row5_col5, #T_9ecc8_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9ecc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ecc8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9ecc8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9ecc8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9ecc8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9ecc8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9ecc8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9ecc8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ecc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ecc8_row0_col0" class="data row0 col0" >0.7695</td>
#       <td id="T_9ecc8_row0_col1" class="data row0 col1" >0.8460</td>
#       <td id="T_9ecc8_row0_col2" class="data row0 col2" >0.8329</td>
#       <td id="T_9ecc8_row0_col3" class="data row0 col3" >0.7723</td>
#       <td id="T_9ecc8_row0_col4" class="data row0 col4" >0.8015</td>
#       <td id="T_9ecc8_row0_col5" class="data row0 col5" >0.5277</td>
#       <td id="T_9ecc8_row0_col6" class="data row0 col6" >0.5299</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ecc8_row1_col0" class="data row1 col0" >0.7543</td>
#       <td id="T_9ecc8_row1_col1" class="data row1 col1" >0.8219</td>
#       <td id="T_9ecc8_row1_col2" class="data row1 col2" >0.8286</td>
#       <td id="T_9ecc8_row1_col3" class="data row1 col3" >0.7552</td>
#       <td id="T_9ecc8_row1_col4" class="data row1 col4" >0.7902</td>
#       <td id="T_9ecc8_row1_col5" class="data row1 col5" >0.4952</td>
#       <td id="T_9ecc8_row1_col6" class="data row1 col6" >0.4983</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9ecc8_row2_col0" class="data row2 col0" >0.7595</td>
#       <td id="T_9ecc8_row2_col1" class="data row2 col1" >0.8242</td>
#       <td id="T_9ecc8_row2_col2" class="data row2 col2" >0.8321</td>
#       <td id="T_9ecc8_row2_col3" class="data row2 col3" >0.7601</td>
#       <td id="T_9ecc8_row2_col4" class="data row2 col4" >0.7945</td>
#       <td id="T_9ecc8_row2_col5" class="data row2 col5" >0.5062</td>
#       <td id="T_9ecc8_row2_col6" class="data row2 col6" >0.5092</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9ecc8_row3_col0" class="data row3 col0" >0.7576</td>
#       <td id="T_9ecc8_row3_col1" class="data row3 col1" >0.8174</td>
#       <td id="T_9ecc8_row3_col2" class="data row3 col2" >0.8285</td>
#       <td id="T_9ecc8_row3_col3" class="data row3 col3" >0.7592</td>
#       <td id="T_9ecc8_row3_col4" class="data row3 col4" >0.7923</td>
#       <td id="T_9ecc8_row3_col5" class="data row3 col5" >0.5026</td>
#       <td id="T_9ecc8_row3_col6" class="data row3 col6" >0.5054</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9ecc8_row4_col0" class="data row4 col0" >0.7766</td>
#       <td id="T_9ecc8_row4_col1" class="data row4 col1" >0.8400</td>
#       <td id="T_9ecc8_row4_col2" class="data row4 col2" >0.8328</td>
#       <td id="T_9ecc8_row4_col3" class="data row4 col3" >0.7814</td>
#       <td id="T_9ecc8_row4_col4" class="data row4 col4" >0.8063</td>
#       <td id="T_9ecc8_row4_col5" class="data row4 col5" >0.5430</td>
#       <td id="T_9ecc8_row4_col6" class="data row4 col6" >0.5445</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_9ecc8_row5_col0" class="data row5 col0" >0.7635</td>
#       <td id="T_9ecc8_row5_col1" class="data row5 col1" >0.8299</td>
#       <td id="T_9ecc8_row5_col2" class="data row5 col2" >0.8310</td>
#       <td id="T_9ecc8_row5_col3" class="data row5 col3" >0.7657</td>
#       <td id="T_9ecc8_row5_col4" class="data row5 col4" >0.7970</td>
#       <td id="T_9ecc8_row5_col5" class="data row5 col5" >0.5149</td>
#       <td id="T_9ecc8_row5_col6" class="data row5 col6" >0.5175</td>
#     </tr>
#     <tr>
#       <th id="T_9ecc8_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_9ecc8_row6_col0" class="data row6 col0" >0.0083</td>
#       <td id="T_9ecc8_row6_col1" class="data row6 col1" >0.0111</td>
#       <td id="T_9ecc8_row6_col2" class="data row6 col2" >0.0020</td>
#       <td id="T_9ecc8_row6_col3" class="data row6 col3" >0.0097</td>
#       <td id="T_9ecc8_row6_col4" class="data row6 col4" >0.0060</td>
#       <td id="T_9ecc8_row6_col5" class="data row6 col5" >0.0177</td>
#       <td id="T_9ecc8_row6_col6" class="data row6 col6" >0.0171</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(blended)

# %%
# blended = blend_models(estimator_list = best_1, fold = 5, method = 'soft')

# %%
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1dad8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dad8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1dad8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1dad8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1dad8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1dad8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1dad8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1dad8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1dad8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dad8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dad8_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_1dad8_row0_col1" class="data row0 col1" >0.7701</td>
#       <td id="T_1dad8_row0_col2" class="data row0 col2" >0.8344</td>
#       <td id="T_1dad8_row0_col3" class="data row0 col3" >0.8279</td>
#       <td id="T_1dad8_row0_col4" class="data row0 col4" >0.7666</td>
#       <td id="T_1dad8_row0_col5" class="data row0 col5" >0.7961</td>
#       <td id="T_1dad8_row0_col6" class="data row0 col6" >0.5334</td>
#       <td id="T_1dad8_row0_col7" class="data row0 col7" >0.5355</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![image.png](attachment:172eda61-250c-48b0-b679-06c7894e26e2.png)

# %%
final_model = finalize_model(blended)

# %%
predictions = predict_model(final_model, data = test)

# %%
predictions['Score']
# Out:
# 0        0.5498
# 1        0.8563
# 2        0.8669
# 3        0.6120
# 4        0.8080
#           ...
# 35447    0.8212
# 35448    0.8467
# 35449    0.9443
# 35450    0.6265
# 35451    0.6855
# Name: Score, Length: 35452, dtype: float64

# %%
predictions['Label']
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 35447    1
# 35448    1
# 35449    1
# 35450    0
# 35451    1
# Name: Label, Length: 35452, dtype: int32

# %%
predictions.loc[predictions['Label'] == 0, 'Score'] = 1 - predictions.loc[predictions['Label'] == 0, 'Score']

# %%
predictions['Score']
# Out:
# 0        0.4502
# 1        0.8563
# 2        0.8669
# 3        0.6120
# 4        0.8080
#           ...
# 35447    0.8212
# 35448    0.8467
# 35449    0.9443
# 35450    0.3735
# 35451    0.6855
# Name: Score, Length: 35452, dtype: float64

# %%
sub = predictions['Score']

# %%
sub
# Out:
# 0        0.4502
# 1        0.8563
# 2        0.8669
# 3        0.6120
# 4        0.8080
#           ...
# 35447    0.8212
# 35448    0.8467
# 35449    0.9443
# 35450    0.3735
# 35451    0.6855
# Name: Score, Length: 35452, dtype: float64

# %%
submission = pd.read_csv('./data/sample_submission.csv')

submission['nerdiness'] = sub

# %%
submission
# Out:
#        index  nerdiness
# 0          0     0.4502
# 1          1     0.8563
# 2          2     0.8669
# 3          3     0.6120
# 4          4     0.8080
# ...      ...        ...
# 35447  35447     0.8212
# 35448  35448     0.8467
# 35449  35449     0.9443
# 35450  35450     0.3735
# 35451  35451     0.6855
#
# [35452 rows x 2 columns]

# %%
submission.to_csv("./submit/submit7.csv", index = False)
